# %%
# Importing the pandas module
import pandas as pd
from datetime import datetime  # To manually create dates 
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Read data into DataFrame
#main_df = pd.read_csv((open('data/cbg_patterns.csv')),usecols=['date_range_start', 'date_range_end','raw_visit_count','raw_visitor_count'])
main_df = pd.read_csv((open('data/cbg_patterns.csv')))
main_df[["date_range_start", "date_range_end"]] = main_df[["date_range_start", "date_range_end"]].apply(pd.to_datetime)
main_df
main_df.dropna(axis=0)
# Out:
#         ï»¿census_block_group           date_range_start  \
# 0                1.005951e+10 1970-01-01 00:00:01.538352
# 1                1.009051e+10 1970-01-01 00:00:01.538352
# 2                1.047957e+10 1970-01-01 00:00:01.538352
# 3                1.069040e+10 1970-01-01 00:00:01.538352
# 4                1.073011e+10 1970-01-01 00:00:01.538352
# 5                1.097006e+10 1970-01-01 00:00:01.538352
# 6                1.103006e+10 1970-01-01 00:00:01.538352
# 7                1.115040e+10 1970-01-01 00:00:01.538352
# 8                2.020001e+10 1970-01-01 00:00:01.538352
# 9                4.001944e+10 1970-01-01 00:00:01.538352
# 10               4.013093e+10 1970-01-01 00:00:01.538352
# 11               4.013103e+10 1970-01-01 00:00:01.538352
# 12               4.013117e+10 1970-01-01 00:00:01.538352
# 13               4.013619e+10 1970-01-01 00:00:01.538352
# 14               4.019004e+10 1970-01-01 00:00:01.538352
# ...

# %%
sns.set(style="darkgrid")

# Plotting visit count and visitor top_brands
plt.plot(main_df['ï»¿census_block_group'], main_df['raw_visit_count'])

# Adding some nice labels 
plt.xlabel('Census Block Group') 
plt.ylabel('Visit Count')

# %%
plt.plot(main_df['ï»¿census_block_group'], main_df['raw_visitor_count'])

# Adding some nice labels 
plt.xlabel('Census Block Group') 
plt.ylabel('Visitor Count')
